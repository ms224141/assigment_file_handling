# %% [markdown]
# <a href="https://colab.research.google.com/github/ms224141/assigment_file_handling/blob/main/simple_linerar_regression_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/height-weight.csv")

# %%
df
# Out:
#     Weight  Height
# 0       45     120
# 1       58     135
# 2       48     123
# 3       60     145
# 4       70     160
# 5       78     162
# 6       80     163
# 7       90     175
# 8       95     182
# 9       78     170
# 10      82     176
# 11      95     182
# 12     105     175
# 13     100     183
# 14      85     170
# 15      78     177
# 16      50     140
# 17      65     159
# 18      76     150
# 19      87     167
# 20      45     129
# 21      56     140
# 22      72     160

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
plt.scatter(df["Height"],df["Weight"])
plt.xlabel("Height")
plt.ylabel("Weight")
# Out:
# Text(0, 0.5, 'Weight')

# %%
# problem>> i wnt to pridict height based on weight

# %%
# devide the data into x and y

# %%
x=df["Weight"]
y=df["Height"]

# %%
x
# Out:
# 0      45
# 1      58
# 2      48
# 3      60
# 4      70
# 5      78
# 6      80
# 7      90
# 8      95
# 9      78
# 10     82
# 11     95
# 12    105
# 13    100
# 14     85
# 15     78
# 16     50
# 17     65
# 18     76
# 19     87
# 20     45
# 21     56
# 22     72
# Name: Weight, dtype: int64

# %%
#  now perform train test split
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train
# Out:
# 16     50
# 10     82
# 4      70
# 2      48
# 18     76
# 6      80
# 7      90
# 1      58
# 14     85
# 0      45
# 15     78
# 22     72
# 21     56
# 9      78
# 8      95
# 12    105
# 11     95
# 5      78
# Name: Weight, dtype: int64

# %%
#  scaling is optional but we will do this there
# we will apply standraization
# by applying z score
#  fit_transform on train data but transform on test data
# if you r doing fit on test data it will lead upto data leakage sp we have to avoid this

# %%
from sklearn.preprocessing import StandardScaler

# %%
standarized = StandardScaler()

# %%
standarized
# Out:
# StandardScaler()

# %%
x_train=standarized.fit_transform(x_train.values.reshape(-1, 1)) # Reshape x_train to a 2D array

# %%
y_train=standarized.fit_transform(y_train.values.reshape(-1,1))

# %%
x_test=standarized.transform(x_test.reshape(-1,1)) # Remove .values and directly reshape

# %%
y_test=standarized.transform(y_test.values.reshape(-1,1))

# %%
#  now impliment machine learning model in it
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
r2_score(y_test,y_pred)
# Out:
# -61.027736694319344

# %%
mst=mean_squared_error(y_pred,y_test)

# %%
mst
# Out:
# 57.34510392009294
